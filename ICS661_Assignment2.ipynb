# %% [markdown]
# <a href="https://colab.research.google.com/github/Akeshh/ICS661-Assignment2/blob/main/ICS661_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os
from tqdm import tqdm
import spacy
from nltk.corpus import stopwords
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import matplotlib.pyplot as plt
import nltk
import string
# Load spaCy's English model
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
nltk.download('stopwords')
# Create stop words set once outside the function
stop_words = set(stopwords.words('english')).union(ENGLISH_STOP_WORDS)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Oct  8 02:49:54 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   38C    P8              16W /  72W |      4MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
#!unzip "/content/drive/MyDrive/CS661-Assignment2/train.zip"  -d "/content/drive/MyDrive/CS661-Assignment2/train_unziped"
#!unzip "/content/drive/MyDrive/CS661-Assignment2/test.zip"  -d "/content/drive/MyDrive/CS661-Assignment2/test_unziped"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5500_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5501_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5502_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5503_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5504_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5505_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5506_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5507_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5508_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5509_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/550_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5510_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5511_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5512_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5513_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5514_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5515_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5516_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5517_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5518_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5519_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/551_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5520_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5521_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5522_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5523_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5524_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5525_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5526_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5527_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5528_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5529_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/552_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5530_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5531_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5532_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5533_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5534_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5535_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5536_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5537_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5538_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5539_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/553_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5540_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5541_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5542_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5543_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5544_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5545_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5546_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5547_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5548_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5549_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/554_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5550_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5551_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5552_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5553_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5554_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5555_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5556_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5557_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5558_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5559_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/555_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5560_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5561_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5562_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5563_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5564_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5565_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5566_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5567_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5568_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5569_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/556_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5570_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5571_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5572_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5573_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5574_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5575_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5576_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5577_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5578_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5579_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/557_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5580_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5581_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5582_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5583_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5584_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5585_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5586_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5587_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5588_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5589_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/558_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5590_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5591_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5592_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5593_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5594_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5595_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5596_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5597_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5598_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5599_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/559_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/55_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5600_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5601_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5602_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5603_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5604_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5605_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5606_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5607_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5608_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5609_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/560_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5610_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5611_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5612_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5613_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5614_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5615_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5616_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5617_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5618_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5619_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/561_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5620_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5621_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5622_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5623_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5624_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5625_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5626_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5627_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5628_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5629_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/562_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5630_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5631_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5632_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5633_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5634_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5635_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5636_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5637_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5638_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5639_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/563_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5640_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5641_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5642_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5643_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5644_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5645_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5646_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5647_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5648_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5649_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/564_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5650_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5651_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5652_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5653_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5654_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5655_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5656_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5657_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5658_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5659_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/565_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5660_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5661_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5662_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5663_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5664_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5665_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5666_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5667_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5668_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5669_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/566_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5670_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5671_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5672_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5673_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5674_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5675_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5676_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5677_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5678_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5679_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/567_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5680_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5681_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5682_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5683_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5684_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5685_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5686_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5687_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5688_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5689_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/568_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5690_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5691_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5692_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5693_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5694_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5695_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5696_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5697_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5698_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5699_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/569_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/56_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5700_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5701_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5702_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5703_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5704_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5705_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5706_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5707_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5708_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5709_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/570_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5710_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5711_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5712_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5713_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5714_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5715_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5716_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5717_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5718_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5719_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/571_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5720_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5721_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5722_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5723_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5724_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5725_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5726_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5727_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5728_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5729_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/572_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5730_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5731_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5732_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5733_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5734_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5735_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5736_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5737_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5738_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5739_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/573_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5740_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5741_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5742_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5743_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5744_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5745_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5746_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5747_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5748_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5749_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/574_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5750_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5751_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5752_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5753_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5754_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5755_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5756_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5757_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5758_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5759_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/575_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5760_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5761_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5762_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5763_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5764_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5765_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5766_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5767_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5768_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5769_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/576_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5770_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5771_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5772_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5773_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5774_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5775_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5776_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5777_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5778_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5779_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/577_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5780_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5781_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5782_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5783_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5784_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5785_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5786_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5787_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5788_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5789_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/578_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5790_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5791_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5792_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5793_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5794_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5795_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5796_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5797_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5798_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5799_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/579_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/57_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5800_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5801_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5802_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5803_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5804_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5805_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5806_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5807_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5808_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5809_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/580_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5810_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5811_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5812_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5813_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5814_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5815_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5816_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5817_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5818_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5819_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/581_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5820_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5821_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5822_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5823_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5824_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5825_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5826_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5827_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5828_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5829_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/582_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5830_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5831_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5832_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5833_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5834_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5835_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5836_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5837_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5838_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5839_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/583_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5840_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5841_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5842_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5843_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5844_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5845_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5846_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5847_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5848_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5849_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/584_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5850_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5851_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5852_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5853_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5854_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5855_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5856_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5857_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5858_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5859_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/585_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5860_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5861_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5862_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5863_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5864_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5865_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5866_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5867_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5868_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5869_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/586_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5870_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5871_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5872_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5873_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5874_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5875_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5876_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5877_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5878_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5879_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/587_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5880_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5881_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5882_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5883_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5884_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5885_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5886_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5887_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5888_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5889_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/588_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5890_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5891_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5892_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5893_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5894_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5895_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5896_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5897_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5898_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5899_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/589_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/58_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5900_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5901_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5902_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5903_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5904_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5905_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5906_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5907_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5908_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5909_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/590_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5910_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5911_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5912_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5913_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5914_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5915_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5916_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5917_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5918_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5919_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/591_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5920_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5921_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5922_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5923_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5924_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5925_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5926_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5927_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5928_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5929_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/592_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5930_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5931_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5932_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5933_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5934_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5935_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5936_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5937_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5938_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5939_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/593_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5940_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5941_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5942_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5943_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5944_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5945_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5946_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5947_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5948_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5949_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/594_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5950_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5951_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5952_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5953_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5954_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5955_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5956_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5957_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5958_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5959_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/595_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5960_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5961_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5962_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5963_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5964_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5965_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5966_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5967_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5968_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5969_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/596_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5970_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5971_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5972_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/5973_9.txt
# ...
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9844_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9845_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9846_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9847_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9848_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9849_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/984_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9850_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9851_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9852_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9853_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9854_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9855_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9856_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9857_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9858_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9859_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/985_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9860_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9861_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9862_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9863_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9864_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9865_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9866_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9867_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9868_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9869_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/986_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9870_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9871_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9872_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9873_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9874_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9875_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9876_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9877_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9878_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9879_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/987_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9880_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9881_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9882_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9883_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9884_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9885_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9886_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9887_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9888_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9889_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/988_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9890_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9891_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9892_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9893_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9894_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9895_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9896_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9897_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9898_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9899_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/989_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/98_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9900_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9901_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9902_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9903_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9904_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9905_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9906_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9907_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9908_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9909_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/990_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9910_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9911_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9912_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9913_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9914_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9915_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9916_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9917_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9918_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9919_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/991_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9920_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9921_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9922_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9923_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9924_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9925_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9926_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9927_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9928_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9929_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/992_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9930_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9931_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9932_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9933_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9934_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9935_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9936_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9937_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9938_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9939_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/993_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9940_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9941_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9942_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9943_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9944_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9945_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9946_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9947_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9948_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9949_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/994_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9950_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9951_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9952_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9953_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9954_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9955_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9956_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9957_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9958_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9959_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/995_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9960_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9961_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9962_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9963_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9964_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9965_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9966_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9967_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9968_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9969_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/996_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9970_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9971_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9972_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9973_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9974_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9975_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9976_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9977_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9978_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9979_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/997_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9980_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9981_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9982_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9983_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9984_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9985_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9986_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9987_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9988_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9989_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/998_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9990_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9991_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9992_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9993_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9994_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9995_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9996_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9997_7.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9998_9.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9999_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/999_10.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/99_8.txt
#   inflating: /content/drive/MyDrive/CS661-Assignment2/train_unziped/train/pos/9_7.txt

# %%
# Combine NLTK and scikit-learn stop words
all_stop_words = set(stopwords.words('english')).union(ENGLISH_STOP_WORDS)

# Get all punctuation
all_punctuation = string.punctuation

# Print the complete list of stopwords and punctuation
print("Stop words:", all_stop_words)
print("Punctuation:", all_punctuation)
# Out:
# Stop words: {'have', 'as', 'or', 'ltd', 'upon', 'eight', 'us', 'before', 'she', "shan't", 'everyone', 'no', "should've", 'are', 'between', 'namely', 'would', 'over', 'bottom', 'somehow', 'fifty', 'often', 'hereafter', 'towards', 'thru', 'down', 'has', 'next', 'himself', 'this', 'rather', 'give', 'seem', 'her', 'what', 'beyond', 'hereupon', 'until', 'should', 'own', "couldn't", "shouldn't", 'behind', 'across', 'must', 'themselves', 'whereupon', 'fifteen', 'him', 'at', 'ma', 'get', 'how', 'describe', 'a', 'meanwhile', 'could', 'did', 'is', 'ain', 'empty', 'onto', 'whoever', 'front', 're', 'hundred', 'ten', 'cannot', 'alone', 'whose', 'me', 'didn', 'wouldn', 'hers', 'thence', 'they', 'nobody', 'still', "wasn't", 'almost', 'against', 'haven', 'very', 'been', 'which', 'five', 'latter', 'otherwise', 'up', 'three', 'else', 'co', 'along', 'therein', 'his', 'bill', 'well', 'mostly', 'aren', 'ever', 'these', 'hasnt', 'latterly', 'every', 'nowhere', 'such', "you'll", 'wherein', 'etc', 'your', 'seems', 'thus', 'if', 'does', 'sixty', 'go', 'herself', 'an', 'other', 'amongst', 'elsewhere', 'it', 'within', "weren't", 'who', 'even', 'doesn', 'made', 'wasn', 'whole', 'anything', "mustn't", "you've", 'side', 'not', 'off', 'where', 'yours', 'thereby', 'through', "didn't", 'put', 'con', "she's", 'each', 'de', 'cant', 'find', 'much', 'due', 'however', 'yourselves', 'neither', 'its', 'were', 'will', 'our', 'm', 'mustn', 'always', 'part', 'except', 'amount', 'eg', 'whom', 'first', 'o', 'sometime', 'perhaps', 'most', 'others', 'with', 'into', 'couldnt', "won't", 'none', 'below', 'because', 'whence', 'least', 'last', 'same', 'thereupon', 'from', 'anyhow', 'two', 'fire', "wouldn't", 'becomes', 'ourselves', 'the', 'i', 'system', 'we', 'under', 'inc', 'might', 'some', 'thereafter', 'throughout', 'several', 'only', 'shan', 'mine', 'you', 'noone', 'there', 'many', 'just', "it's", 'to', 'of', 'anyone', 'beside', 'moreover', 'seemed', 'anyway', 'please', 'so', 'sincere', 'hadn', 'show', 'full', 'top', 'six', 'having', 'itself', 'now', 'd', "doesn't", 'whither', 'sometimes', 'less', 'but', 'whereby', 'either', 'shouldn', 'move', 'doing', 'mill', 'further', 'see', 'my', 'couldn', 'wherever', 'herein', 'while', 'too', 'both', "haven't", "that'll", 'do', 'needn', 'don', 'somewhere', 'he', 'former', "you're", 'those', 'become', 'became', 'll', 'weren', "aren't", 'another', 'call', 'then', 'am', 't', 'in', 'myself', 'their', 'toward', 'ours', 'any', 'among', 'name', 'fill', 've', 'twelve', 'anywhere', 'therefore', 'found', "hasn't", 'indeed', 'four', 'again', 'someone', 'than', 'since', 'beforehand', 'being', 'out', 'thin', 'was', 'more', 'won', 'everything', 'serious', 'whenever', 'above', 'mightn', 'may', 'by', 'on', 'also', 'whereafter', "needn't", 'detail', 'theirs', 'around', 'enough', 'third', 'hereby', 'nine', 'cry', 'yourself', 's', 'few', "mightn't", 'back', "you'd", 'that', 'when', 'once', 'formerly', 'take', 'though', 'done', 'nor', 'ie', 'without', 'amoungst', 'via', 'during', 'whereas', 'here', 'never', 'everywhere', 'had', 'one', "isn't", 'be', 'whatever', 'twenty', "hadn't", 'them', 'isn', 'hasn', 'interest', 'per', 'why', "don't", 'un', 'although', 'about', 'for', 'y', 'afterwards', 'something', 'nothing', 'hence', 'eleven', 'nevertheless', 'forty', 'keep', 'can', 'all', 'becoming', 'seeming', 'together', 'already', 'yet', 'and', 'after', 'thick', 'whether', 'besides'}
# Punctuation: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Define the text cleaning function using spaCy
def clean_text(text):
    # Convert to lowercase and remove punctuation in one step using spaCy
    doc = nlp(text.lower())  # Tokenization happens here
    tokens = [token.text for token in doc if token.text not in stop_words and not token.is_punct]
    return ' '.join(tokens)

# Define the function to load data and labels
def load_data(directory):
    data = []
    for label in ['pos', 'neg']:
        label_dir = os.path.join(directory, label)
        for filename in tqdm(os.listdir(label_dir), desc=f"Processing {label} files in {directory}"):
            if filename.endswith('.txt'):
                score = int(filename.split('_')[1].split('.')[0])
                # Exclude neutral scores (5 and 6)
                if score in [5, 6]:
                    continue
                # Assign labels: 'pos' for positive, 'neg' for negative
                label_value = 'pos' if score >= 7 else 'neg'
                with open(os.path.join(label_dir, filename), 'r', encoding='utf-8') as file:
                    review = file.read()
                    cleaned_review = clean_text(review)
                    data.append({'review': cleaned_review, 'label': label_value, 'score': score})
    return data

# Load and preprocess the data
train_data = load_data('/content/drive/MyDrive/CS661-Assignment2/train')
test_data = load_data('/content/drive/MyDrive/CS661-Assignment2/test')

# Save the processed data to JSON files
with open('/content/drive/MyDrive/CS661-Assignment2/train_data.json', 'w') as train_file:
    json.dump(train_data, train_file)

with open('/content/drive/MyDrive/CS661-Assignment2/test_data.json', 'w') as test_file:
    json.dump(test_data, test_file)

print("Data saved to JSON files.")

# %%
# Load and print a portion of the train and test data
with open('/content/drive/MyDrive/CS661-Assignment2/train_data.json', 'r') as train_file, open('/content/drive/MyDrive/CS661-Assignment2/test_data.json', 'r') as test_file:
    train_data = json.load(train_file)
    test_data = json.load(test_file)

print("Train data example:", train_data[:1])
print("Test data example:", test_data[:1])
# Out:
# Train data example: [{'review': "bromwell high cartoon comedy ran time programs school life teachers 35 years teaching profession lead believe bromwell high 's satire closer reality teachers scramble survive financially insightful students right pathetic teachers pomp pettiness situation remind schools knew students saw episode student repeatedly tried burn school immediately recalled high classic line inspector 'm sack teachers student welcome bromwell high expect adults age think bromwell high far fetched pity n't", 'label': 'pos', 'score': 9}]
# Test data example: [{'review': "went saw movie night coaxed friends 'll admit reluctant knew ashton kutcher able comedy wrong kutcher played character jake fischer kevin costner played ben randall professionalism sign good movie toy emotions exactly entire theater sold overcome laughter half movie moved tears second half exiting theater saw women tears grown men trying desperately let crying movie great suggest judge", 'label': 'pos', 'score': 10}]

# %%
# Combine both train and test data to calculate overall average review length
all_data = train_data + test_data

# Calculate the average length of 'review'
total_length = sum(len(item['review'].split()) for item in all_data)
average_length = total_length / len(all_data)

average_length
# Out:
# 113.78442

# %%
import torch
import torch.nn as nn
from transformers import AutoModel, AutoTokenizer
# Tokenizer for BERT
bert_model_name = 'cardiffnlp/twitter-roberta-base-sentiment-latest'  # You can use other variants such as 'bert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(bert_model_name)

# Function to tokenize and convert input data for BERT with tqdm progress bar
def preprocess_for_bert(texts, tokenizer, max_len=256):
    # Prepare empty lists to store tokenized inputs and attention masks
    input_ids_list = []
    attention_mask_list = []

    # Use tqdm to show the progress of tokenization
    for text in tqdm(texts, desc="Tokenizing data"):
        encoding = tokenizer(text, truncation=True, padding='max_length', max_length=max_len, return_tensors='pt')
        input_ids_list.append(encoding['input_ids'])
        attention_mask_list.append(encoding['attention_mask'])

    # Stack them together into tensors
    input_ids = torch.cat(input_ids_list, dim=0)
    attention_mask = torch.cat(attention_mask_list, dim=0)

    return input_ids, attention_mask

# Read reviews and labels from the JSON data
train_reviews = [item['review'] for item in tqdm(train_data, desc="Reading train data")]
train_labels = [1 if item['label'] == 'pos' else 0 for item in train_data]

test_reviews = [item['review'] for item in tqdm(test_data, desc="Reading test data")]
test_labels = [1 if item['label'] == 'pos' else 0 for item in test_data]

# Preprocess the reviews using BERT tokenizer with progress bars
train_input_ids, train_attention_mask = preprocess_for_bert(train_reviews, tokenizer)
test_input_ids, test_attention_mask = preprocess_for_bert(test_reviews, tokenizer)

# Convert labels to tensors
train_labels = torch.tensor(train_labels, dtype=torch.float32)
test_labels = torch.tensor(test_labels, dtype=torch.float32)

# Create TensorDataset with input_ids, attention_mask, and labels
train_dataset = TensorDataset(train_input_ids, train_attention_mask, train_labels)
test_dataset = TensorDataset(test_input_ids, test_attention_mask, test_labels)


print("Data loaded and prepared for BERT.")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Reading train data: 100%|██████████| 25000/25000 [00:00<00:00, 2007036.08it/s]
# Reading test data: 100%|██████████| 25000/25000 [00:00<00:00, 2287469.46it/s]
# Tokenizing data: 100%|██████████| 25000/25000 [00:20<00:00, 1237.76it/s]
# Tokenizing data: 100%|██████████| 25000/25000 [00:19<00:00, 1276.13it/s]
# Data loaded and prepared for BERT.

# %%
import torch
import torch.nn as nn
from transformers import AutoModel

# Define a new model class that uses BERT embeddings
class SentimentBERT(nn.Module):
    def __init__(self, bert_model_name, hidden_size, output_size, drop_prob=0.5):
        super(SentimentBERT, self).__init__()
        self.hidden_size = hidden_size

        # Load the BERT model
        self.bert = AutoModel.from_pretrained(bert_model_name)


        # Define RNN layer (or you can use GRU/LSTM instead)
        self.rnn = nn.RNN(self.bert.config.hidden_size, hidden_size, batch_first=True)

        # Fully connected layer for classification (output_size changed to 2 for binary classification with CrossEntropyLoss)
        self.fc = nn.Linear(hidden_size, output_size)

        # Dropout layer
        self.dropout = nn.Dropout(drop_prob)


    def forward(self, input_ids, attention_mask):
        # Pass the inputs through BERT to get the contextualized embeddings
        bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = bert_output.last_hidden_state  # Get the last hidden states

        # Pass through RNN
        rnn_out, _ = self.rnn(last_hidden_state)

        # Apply dropout and pass through fully connected layer
        out = self.dropout(rnn_out[:, -1, :])  # Get the last output from RNN
        out = self.fc(out)

        return out

# Define the model
hidden_size = 128
output_size = 2  # Output size is 2 for binary classification with CrossEntropyLoss
model = SentimentBERT(bert_model_name, hidden_size, output_size)

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(model)

# Loss function (CrossEntropyLoss)
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# SentimentBERT(
#   (bert): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (rnn): RNN(768, 128, batch_first=True)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
def train_model(model, train_loader, test_loader, criterion, optimizer, n_epochs=10, device='cpu'):
    # Track loss and accuracy history
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    model.to(device)  # Ensure model is on the correct device

    for epoch in range(n_epochs):
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        # Training loop with tqdm progress bar
        train_loader_iter = tqdm(train_loader, desc=f"Epoch {epoch+1}/{n_epochs} Training")
        for input_ids, attention_mask, labels in train_loader_iter:
            # Move input data to the appropriate device
            input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

            optimizer.zero_grad()

            # Forward pass through the model
            outputs = model(input_ids, attention_mask)

            # CrossEntropyLoss expects labels as long, and no need for sigmoid
            loss = criterion(outputs, labels.long())

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

            # Accumulate loss
            running_loss += loss.item() * input_ids.size(0)

            # Accuracy calculation: outputs are logits, take argmax for predictions
            preds = torch.argmax(outputs, dim=1)
            correct_train += (preds == labels).sum().item()
            total_train += labels.size(0)

            # Debugging: Print predictions and labels (optional)
            if epoch == 0 and total_train < 100:  # Only print for the first epoch and small batch for readability
                print(f"Predictions: {preds[:10]}")  # Print first 10 predictions
                print(f"Labels: {labels[:10]}")      # Print first 10 labels

        train_loss = running_loss / total_train
        train_acc = correct_train / total_train

        # Append train metrics
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        # Evaluate on test set with progress bar
        test_loss, test_acc = evaluate_model(model, test_loader, criterion, device)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        print(f'Epoch {epoch+1}/{n_epochs} - Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, '
              f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}')

    return train_losses, train_accuracies, test_losses, test_accuracies


def evaluate_model(model, data_loader, criterion, device='cpu'):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        data_loader_iter = tqdm(data_loader, desc="Evaluating")
        for input_ids, attention_mask, labels in data_loader_iter:
            # Move input data to the appropriate device
            input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

            # Forward pass through the model
            outputs = model(input_ids, attention_mask)

            # CrossEntropyLoss expects labels as long, no need for sigmoid
            loss = criterion(outputs, labels.long())

            running_loss += loss.item() * input_ids.size(0)

            # Accuracy calculation: outputs are logits, take argmax for predictions
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

            # Debugging: Print predictions and labels for the first few batches
            if total < 100:  # Only print for the first 100 samples for readability
                print(f"Predictions: {preds[:10]}")  # Print first 10 predictions
                print(f"Labels: {labels[:10]}")      # Print first 10 labels

    avg_loss = running_loss / total
    accuracy = correct / total  # Ensure accuracy is between 0-1

    # Debugging: print correct and total to verify accuracy calculation
    print(f"Correct: {correct}, Total: {total}, Accuracy: {accuracy}")

    return avg_loss, accuracy


# Function to plot loss and accuracy
def plot_metrics(train_losses, train_accuracies, test_losses, test_accuracies, n_epochs):
    import matplotlib.pyplot as plt

    epochs = range(1, n_epochs + 1)

    # Plot loss
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, test_losses, label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss over Epochs')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, test_accuracies, label='Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy over Epochs')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# initialize a new model
new_model = SentimentBERT(bert_model_name, hidden_size, output_size)

# freeze  parameter
for param in new_model.bert.parameters():
    param.requires_grad = False


new_model.to(device)


for name, param in new_model.named_parameters():
    if param.requires_grad:
        print(f"Training: {name}")
    else:
        print(f"Frozen: {name}")  #


optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, new_model.parameters()), lr=0.001)


criterion = nn.CrossEntropyLoss()
# Out:
# Frozen: bert.embeddings.word_embeddings.weight
# Frozen: bert.embeddings.position_embeddings.weight
# Frozen: bert.embeddings.token_type_embeddings.weight
# Frozen: bert.embeddings.LayerNorm.weight
# Frozen: bert.embeddings.LayerNorm.bias
# Frozen: bert.encoder.layer.0.attention.self.query.weight
# Frozen: bert.encoder.layer.0.attention.self.query.bias
# Frozen: bert.encoder.layer.0.attention.self.key.weight
# Frozen: bert.encoder.layer.0.attention.self.key.bias
# Frozen: bert.encoder.layer.0.attention.self.value.weight
# Frozen: bert.encoder.layer.0.attention.self.value.bias
# Frozen: bert.encoder.layer.0.attention.output.dense.weight
# Frozen: bert.encoder.layer.0.attention.output.dense.bias
# Frozen: bert.encoder.layer.0.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.0.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.0.intermediate.dense.weight
# Frozen: bert.encoder.layer.0.intermediate.dense.bias
# Frozen: bert.encoder.layer.0.output.dense.weight
# Frozen: bert.encoder.layer.0.output.dense.bias
# Frozen: bert.encoder.layer.0.output.LayerNorm.weight
# Frozen: bert.encoder.layer.0.output.LayerNorm.bias
# Frozen: bert.encoder.layer.1.attention.self.query.weight
# Frozen: bert.encoder.layer.1.attention.self.query.bias
# Frozen: bert.encoder.layer.1.attention.self.key.weight
# Frozen: bert.encoder.layer.1.attention.self.key.bias
# Frozen: bert.encoder.layer.1.attention.self.value.weight
# Frozen: bert.encoder.layer.1.attention.self.value.bias
# Frozen: bert.encoder.layer.1.attention.output.dense.weight
# Frozen: bert.encoder.layer.1.attention.output.dense.bias
# Frozen: bert.encoder.layer.1.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.1.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.1.intermediate.dense.weight
# Frozen: bert.encoder.layer.1.intermediate.dense.bias
# Frozen: bert.encoder.layer.1.output.dense.weight
# Frozen: bert.encoder.layer.1.output.dense.bias
# Frozen: bert.encoder.layer.1.output.LayerNorm.weight
# Frozen: bert.encoder.layer.1.output.LayerNorm.bias
# Frozen: bert.encoder.layer.2.attention.self.query.weight
# Frozen: bert.encoder.layer.2.attention.self.query.bias
# Frozen: bert.encoder.layer.2.attention.self.key.weight
# Frozen: bert.encoder.layer.2.attention.self.key.bias
# Frozen: bert.encoder.layer.2.attention.self.value.weight
# Frozen: bert.encoder.layer.2.attention.self.value.bias
# Frozen: bert.encoder.layer.2.attention.output.dense.weight
# Frozen: bert.encoder.layer.2.attention.output.dense.bias
# Frozen: bert.encoder.layer.2.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.2.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.2.intermediate.dense.weight
# Frozen: bert.encoder.layer.2.intermediate.dense.bias
# Frozen: bert.encoder.layer.2.output.dense.weight
# Frozen: bert.encoder.layer.2.output.dense.bias
# Frozen: bert.encoder.layer.2.output.LayerNorm.weight
# Frozen: bert.encoder.layer.2.output.LayerNorm.bias
# Frozen: bert.encoder.layer.3.attention.self.query.weight
# Frozen: bert.encoder.layer.3.attention.self.query.bias
# Frozen: bert.encoder.layer.3.attention.self.key.weight
# Frozen: bert.encoder.layer.3.attention.self.key.bias
# Frozen: bert.encoder.layer.3.attention.self.value.weight
# Frozen: bert.encoder.layer.3.attention.self.value.bias
# Frozen: bert.encoder.layer.3.attention.output.dense.weight
# Frozen: bert.encoder.layer.3.attention.output.dense.bias
# Frozen: bert.encoder.layer.3.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.3.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.3.intermediate.dense.weight
# Frozen: bert.encoder.layer.3.intermediate.dense.bias
# Frozen: bert.encoder.layer.3.output.dense.weight
# Frozen: bert.encoder.layer.3.output.dense.bias
# Frozen: bert.encoder.layer.3.output.LayerNorm.weight
# Frozen: bert.encoder.layer.3.output.LayerNorm.bias
# Frozen: bert.encoder.layer.4.attention.self.query.weight
# Frozen: bert.encoder.layer.4.attention.self.query.bias
# Frozen: bert.encoder.layer.4.attention.self.key.weight
# Frozen: bert.encoder.layer.4.attention.self.key.bias
# Frozen: bert.encoder.layer.4.attention.self.value.weight
# Frozen: bert.encoder.layer.4.attention.self.value.bias
# Frozen: bert.encoder.layer.4.attention.output.dense.weight
# Frozen: bert.encoder.layer.4.attention.output.dense.bias
# Frozen: bert.encoder.layer.4.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.4.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.4.intermediate.dense.weight
# Frozen: bert.encoder.layer.4.intermediate.dense.bias
# Frozen: bert.encoder.layer.4.output.dense.weight
# Frozen: bert.encoder.layer.4.output.dense.bias
# Frozen: bert.encoder.layer.4.output.LayerNorm.weight
# Frozen: bert.encoder.layer.4.output.LayerNorm.bias
# Frozen: bert.encoder.layer.5.attention.self.query.weight
# Frozen: bert.encoder.layer.5.attention.self.query.bias
# Frozen: bert.encoder.layer.5.attention.self.key.weight
# Frozen: bert.encoder.layer.5.attention.self.key.bias
# Frozen: bert.encoder.layer.5.attention.self.value.weight
# Frozen: bert.encoder.layer.5.attention.self.value.bias
# Frozen: bert.encoder.layer.5.attention.output.dense.weight
# Frozen: bert.encoder.layer.5.attention.output.dense.bias
# Frozen: bert.encoder.layer.5.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.5.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.5.intermediate.dense.weight
# Frozen: bert.encoder.layer.5.intermediate.dense.bias
# Frozen: bert.encoder.layer.5.output.dense.weight
# Frozen: bert.encoder.layer.5.output.dense.bias
# Frozen: bert.encoder.layer.5.output.LayerNorm.weight
# Frozen: bert.encoder.layer.5.output.LayerNorm.bias
# Frozen: bert.encoder.layer.6.attention.self.query.weight
# Frozen: bert.encoder.layer.6.attention.self.query.bias
# Frozen: bert.encoder.layer.6.attention.self.key.weight
# Frozen: bert.encoder.layer.6.attention.self.key.bias
# Frozen: bert.encoder.layer.6.attention.self.value.weight
# Frozen: bert.encoder.layer.6.attention.self.value.bias
# Frozen: bert.encoder.layer.6.attention.output.dense.weight
# Frozen: bert.encoder.layer.6.attention.output.dense.bias
# Frozen: bert.encoder.layer.6.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.6.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.6.intermediate.dense.weight
# Frozen: bert.encoder.layer.6.intermediate.dense.bias
# Frozen: bert.encoder.layer.6.output.dense.weight
# Frozen: bert.encoder.layer.6.output.dense.bias
# Frozen: bert.encoder.layer.6.output.LayerNorm.weight
# Frozen: bert.encoder.layer.6.output.LayerNorm.bias
# Frozen: bert.encoder.layer.7.attention.self.query.weight
# Frozen: bert.encoder.layer.7.attention.self.query.bias
# Frozen: bert.encoder.layer.7.attention.self.key.weight
# Frozen: bert.encoder.layer.7.attention.self.key.bias
# Frozen: bert.encoder.layer.7.attention.self.value.weight
# Frozen: bert.encoder.layer.7.attention.self.value.bias
# Frozen: bert.encoder.layer.7.attention.output.dense.weight
# Frozen: bert.encoder.layer.7.attention.output.dense.bias
# Frozen: bert.encoder.layer.7.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.7.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.7.intermediate.dense.weight
# Frozen: bert.encoder.layer.7.intermediate.dense.bias
# Frozen: bert.encoder.layer.7.output.dense.weight
# Frozen: bert.encoder.layer.7.output.dense.bias
# Frozen: bert.encoder.layer.7.output.LayerNorm.weight
# Frozen: bert.encoder.layer.7.output.LayerNorm.bias
# Frozen: bert.encoder.layer.8.attention.self.query.weight
# Frozen: bert.encoder.layer.8.attention.self.query.bias
# Frozen: bert.encoder.layer.8.attention.self.key.weight
# Frozen: bert.encoder.layer.8.attention.self.key.bias
# Frozen: bert.encoder.layer.8.attention.self.value.weight
# Frozen: bert.encoder.layer.8.attention.self.value.bias
# Frozen: bert.encoder.layer.8.attention.output.dense.weight
# Frozen: bert.encoder.layer.8.attention.output.dense.bias
# Frozen: bert.encoder.layer.8.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.8.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.8.intermediate.dense.weight
# Frozen: bert.encoder.layer.8.intermediate.dense.bias
# Frozen: bert.encoder.layer.8.output.dense.weight
# Frozen: bert.encoder.layer.8.output.dense.bias
# Frozen: bert.encoder.layer.8.output.LayerNorm.weight
# Frozen: bert.encoder.layer.8.output.LayerNorm.bias
# Frozen: bert.encoder.layer.9.attention.self.query.weight
# Frozen: bert.encoder.layer.9.attention.self.query.bias
# Frozen: bert.encoder.layer.9.attention.self.key.weight
# Frozen: bert.encoder.layer.9.attention.self.key.bias
# Frozen: bert.encoder.layer.9.attention.self.value.weight
# Frozen: bert.encoder.layer.9.attention.self.value.bias
# Frozen: bert.encoder.layer.9.attention.output.dense.weight
# Frozen: bert.encoder.layer.9.attention.output.dense.bias
# Frozen: bert.encoder.layer.9.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.9.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.9.intermediate.dense.weight
# Frozen: bert.encoder.layer.9.intermediate.dense.bias
# Frozen: bert.encoder.layer.9.output.dense.weight
# Frozen: bert.encoder.layer.9.output.dense.bias
# Frozen: bert.encoder.layer.9.output.LayerNorm.weight
# Frozen: bert.encoder.layer.9.output.LayerNorm.bias
# Frozen: bert.encoder.layer.10.attention.self.query.weight
# Frozen: bert.encoder.layer.10.attention.self.query.bias
# Frozen: bert.encoder.layer.10.attention.self.key.weight
# Frozen: bert.encoder.layer.10.attention.self.key.bias
# Frozen: bert.encoder.layer.10.attention.self.value.weight
# Frozen: bert.encoder.layer.10.attention.self.value.bias
# Frozen: bert.encoder.layer.10.attention.output.dense.weight
# Frozen: bert.encoder.layer.10.attention.output.dense.bias
# Frozen: bert.encoder.layer.10.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.10.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.10.intermediate.dense.weight
# Frozen: bert.encoder.layer.10.intermediate.dense.bias
# Frozen: bert.encoder.layer.10.output.dense.weight
# Frozen: bert.encoder.layer.10.output.dense.bias
# Frozen: bert.encoder.layer.10.output.LayerNorm.weight
# Frozen: bert.encoder.layer.10.output.LayerNorm.bias
# Frozen: bert.encoder.layer.11.attention.self.query.weight
# Frozen: bert.encoder.layer.11.attention.self.query.bias
# Frozen: bert.encoder.layer.11.attention.self.key.weight
# Frozen: bert.encoder.layer.11.attention.self.key.bias
# Frozen: bert.encoder.layer.11.attention.self.value.weight
# Frozen: bert.encoder.layer.11.attention.self.value.bias
# Frozen: bert.encoder.layer.11.attention.output.dense.weight
# Frozen: bert.encoder.layer.11.attention.output.dense.bias
# Frozen: bert.encoder.layer.11.attention.output.LayerNorm.weight
# Frozen: bert.encoder.layer.11.attention.output.LayerNorm.bias
# Frozen: bert.encoder.layer.11.intermediate.dense.weight
# Frozen: bert.encoder.layer.11.intermediate.dense.bias
# Frozen: bert.encoder.layer.11.output.dense.weight
# Frozen: bert.encoder.layer.11.output.dense.bias
# Frozen: bert.encoder.layer.11.output.LayerNorm.weight
# Frozen: bert.encoder.layer.11.output.LayerNorm.bias
# Frozen: bert.pooler.dense.weight
# Frozen: bert.pooler.dense.bias
# Training: rnn.weight_ih_l0
# Training: rnn.weight_hh_l0
# Training: rnn.bias_ih_l0
# Training: rnn.bias_hh_l0
# Training: fc.weight
# Training: fc.bias

# %%
n_epochs = 10
train_losses, train_accuracies, test_losses, test_accuracies = train_model(
    new_model, train_loader, test_loader, criterion, optimizer, n_epochs=n_epochs, device=device
)

plot_metrics(train_losses, train_accuracies, test_losses, test_accuracies, n_epochs)
# Out:
# Epoch 1/10 Training: 100%|██████████| 49/49 [03:22<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:04<00:00,  3.76s/it]
# Correct: 20314, Total: 25000, Accuracy: 0.81256
# Epoch 1/10 - Train Loss: 0.4804, Train Accuracy: 0.7710, Test Loss: 0.4174, Test Accuracy: 0.8126
# Epoch 2/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:04<00:00,  3.76s/it]
# Correct: 20767, Total: 25000, Accuracy: 0.83068
# Epoch 2/10 - Train Loss: 0.4089, Train Accuracy: 0.8145, Test Loss: 0.3763, Test Accuracy: 0.8307
# Epoch 3/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.15s/it]
# Evaluating: 100%|██████████| 49/49 [03:03<00:00,  3.76s/it]
# Correct: 20910, Total: 25000, Accuracy: 0.8364
# Epoch 3/10 - Train Loss: 0.3922, Train Accuracy: 0.8246, Test Loss: 0.3685, Test Accuracy: 0.8364
# Epoch 4/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.15s/it]
# Evaluating: 100%|██████████| 49/49 [03:04<00:00,  3.76s/it]
# Correct: 20911, Total: 25000, Accuracy: 0.83644
# Epoch 4/10 - Train Loss: 0.3846, Train Accuracy: 0.8297, Test Loss: 0.3683, Test Accuracy: 0.8364
# Epoch 5/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:04<00:00,  3.76s/it]
# Correct: 21033, Total: 25000, Accuracy: 0.84132
# Epoch 5/10 - Train Loss: 0.3814, Train Accuracy: 0.8302, Test Loss: 0.3643, Test Accuracy: 0.8413
# Epoch 6/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:04<00:00,  3.76s/it]
# Correct: 20837, Total: 25000, Accuracy: 0.83348
# Epoch 6/10 - Train Loss: 0.3743, Train Accuracy: 0.8357, Test Loss: 0.3768, Test Accuracy: 0.8335
# Epoch 7/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:04<00:00,  3.76s/it]
# Correct: 21015, Total: 25000, Accuracy: 0.8406
# Epoch 7/10 - Train Loss: 0.3769, Train Accuracy: 0.8326, Test Loss: 0.3674, Test Accuracy: 0.8406
# Epoch 8/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:03<00:00,  3.75s/it]
# Correct: 21044, Total: 25000, Accuracy: 0.84176
# Epoch 8/10 - Train Loss: 0.3673, Train Accuracy: 0.8376, Test Loss: 0.3665, Test Accuracy: 0.8418
# Epoch 9/10 Training: 100%|██████████| 49/49 [03:23<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:04<00:00,  3.76s/it]
# Correct: 20872, Total: 25000, Accuracy: 0.83488
# Epoch 9/10 - Train Loss: 0.3681, Train Accuracy: 0.8384, Test Loss: 0.3928, Test Accuracy: 0.8349
# Epoch 10/10 Training: 100%|██████████| 49/49 [03:22<00:00,  4.14s/it]
# Evaluating: 100%|██████████| 49/49 [03:03<00:00,  3.75s/it]
# Correct: 21030, Total: 25000, Accuracy: 0.8412
# Epoch 10/10 - Train Loss: 0.3729, Train Accuracy: 0.8350, Test Loss: 0.3701, Test Accuracy: 0.8412
